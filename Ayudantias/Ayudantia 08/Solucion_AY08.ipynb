# %% [markdown]
# # Ayudantía: Simulación

# %% [markdown]
# ### Simulación Síncrona
#
# Una forma general de verlo sería:
#
# MIENTRAS el tiempo simulación no termine:
#     - SI ocurren eventos en este intervalo de tiempo:
#         - simular los eventos
#     - Aumentar tiempo en una unidad
#
# Problemas:
#
# - Ejecución lenta
# - Mayoría de incrementos no cambia el estado del sistema
# - Las verificaciones generan pérdida de tiempo en la CPU

# %% [markdown]
# ### Simulación DES
#
# Una forma general de verlo sería:
#
# MIENTRAS la lista de eventos no esté vacía y el tiempo de simulación no termine:
#     - Tomar un evento del principio de la lista de eventos
#     - Avanzar tiempo de simulación al tiempo del evento
#     - Simular el evento
#
#
# o bien,
#
#
# MIENTRAS hayan eventos y el tiempo de simulación no termine:
#     - Encontrar próximo evento
#     - Avanzar tiempo de simulación al tiempo del evento
#     - Simular el evento

# %% [markdown]
# ### Distribuciones
#
# Utilizaremos la libería random.
#
# - `random.choice(secuencia)`: Escoge un elemento aleatorio de una secuencia (ej: lista)
#
# - `random.randint(a, b)`: Para ENTEROS que distribuyen uniforme (a y b incluidos)
#
# - `random.uniform(a, b)`: Para valores que distribuyen uniforme entre [a, b)
#
# - `random.randrange(a, b, step)`: Para valores que distribuyen uniforme entre [a, b)
#
# - `random.expovariate(lambd)`: Para eventos que distribuyen exponencial (lambd ocurrencias cada una unidad de tiempo <=> ocurrencias ocurren en promedio cada 1/lambd tiempo)

# %% [markdown]
# ## Problema
#
# Desde el ministerio de transporte, se te ha pedido que implementes un programa que modele y simule el funcionamiento de sus autopistas, pues quiere ver en qué autopistas se debe licitar nuevas estaciones de servicio y gasolineras. Para esto, te dan las siguientes indicaciones:
#
# >"El programa debe ser capaz de simular el funcionamiento de una ruta que tendrá un largo entre 350 y 500 km (que es la distancia que posee dicha ruta para ser completada) y una probabilidad de que un conductor en auto,  llegue a la ruta distribuye exponencial de tasa lambda (tasa de llegada es una variable aleatoria entre 0.05 y 0.1 vehículos por unidad de tiempo). Cada conductor, puede conducir a una velocidad aleatoria entre entre 1 y 3 km/minuto. Además, cada vehículo gasta entre 0.1 y 0.07 litros por cada kilómetro recorrido. Además de esto, los autos no tienen estanques infinitos, por lo que al momento de ingresar a la ruta, se tiene que su estanque tiene una cantidad entera aleatoria entre 40 y 50 litros. Como no hay estaciones de servicio, un auto puede llegar al final de la ruta, o quedarse en pana en la mitad del trayecto. Finalmente, carabineros realiza control a los autos de manera aleatoria: en promedio cada 15 unidades de tiempo se selecciona un auto en la carretera al azar y se le realiza control durante 5 a 10 unidades de tiempo.  Una vez que la simulación termine, se debe informar cuántos autos se quedaron sin bencina, y cuántos lograron terminar la ruta exitosamente."

# %% [markdown]
# Del enunciado se puede extraer la siguiente entidad:
# - Auto: posee los siguientes atributos:
#     - velocidad: cantidad aleatoria (se asume uniforme) entre 1 y 3 kilómetros por unidad de tiempo.
#     - rendimiento: cantidad aleatoria (se asume uniforme) entre 0.1 y 0.07 litros por kilómetro.
#     - estanque: cantidad aleatoria (se asume uniforme) entre 40 y 50 litros.
#
#
# - Ruta: posee los siguientes atributos:
#     - largo_ruta: cantidad aleatoria (se asume uniforme) entre 350 y 500 kilómetros.
#
# Como la ruta es la entidad que contiene a todos las entidades del sistema, la utilizaremos para realizar la simulación, por lo que se le implementará un método `run` para llevarla a cabo. Desde ahora, se le llamará a las rutas `Simulacion`.
#
# Además, se pueden extraer los siguientes eventos:
#
# - Control de carabineros: afecta a un auto al azar. Ocurre cada 3 unidades de tiempo y no nos dicen la distribución por lo que asumimos uniforme entre 10 y 20 unidades de tiempo (el 10 y 20 fueron completamente arbitrarios :P).
# - Llegada auto a la autopista: crea un nuevo auto que comienza en el comienzo de la ruta. Ocurre a una tasa aleatoria entre 0.05 y 0.1 vehículos por unidad de tiempo que se define al comienzo de la simulación.
#
# Además, para cada vehículo se tienen los siguientes eventos propios de ellos:
# - Pana de vehículo.
# - Llegada de Vehículo.
#
# Sin embargo, para esta simulación simple, ambos corresponden a un mismo evento propio de los autos:
# - Salida de auto: afecta al auto correspondiente. Ocurre cuando un auto llega al final de la ruta, o bien, llega hasta la distancia máxima que su bencina pudo darle.

# %%
from random import expovariate, randint, uniform, choice
import numpy as np

# %%
class Evento:
    def __init__(self, nombre, tiempo, auto=None):
        self.nombre = nombre
        self.tiempo = tiempo
        self.auto = auto

# %%
class Auto:
    num = 0

    def __init__(self, tiempo_inicio, por_recorrer):
        self.tiempo_inicial = tiempo_inicio
        # Variables aleatorias
        self.rendimiento = uniform(0.1, 0.07)   # litros / kilometros
        self.estanque = randint(40, 50)         # litros
        self.velocidad = randint(1, 3)          # kilometros / minuto
        self.por_recorrer = por_recorrer
        self.tiempo_detenido = 0
        # Identificacion de instancias
        self.llega = (self.estanque / self.rendimiento) > por_recorrer   #  bool
        self.id = Auto.num
        Auto.num += 1

    def distancia_recorrida(self, tiempo):
        return round((tiempo - self.tiempo_inicial - self.tiempo_detenido) * self.velocidad, 1)

    @property
    def siguiente_evento(self):
        # Vemos que pasa primero: auto queda en pana o llega
        if self.llega:
            tiempo = self.tiempo_inicial + self.por_recorrer / self.velocidad
            return Evento('salida_ruta', tiempo, self)
        tiempo = self.tiempo_inicial + (self.estanque / self.rendimiento) / self.velocidad
        return Evento('pana', tiempo, self)

# %%
class Simulacion:

    def __init__(self, tiempo_maximo):
        self.tiempo_maximo = tiempo_maximo
        self.tiempo_actual = 0
        self.eventos = list()
        self.autos = list()
        self.autos_pana = 0
        self.autos_terminaron = 0
        self.autos_detenidos = 0
        self.largo_ruta = randint(350, 500)
        self.tasa_llegada_autos = uniform(0.05, 0.1)  #  cada 10 a 20 min sale un auto
        self.metodos = {'nuevo_auto': self.nuevo_auto,
                        'salida_ruta': self.salida_ruta,
                        'pana': self.pana, 'carabineros': self.carabineros}

    def eventos_iniciales(self):
        # asumimos que llega en el tiempo cero el primer auto
        self.eventos.append(Evento('nuevo_auto', 0))
        self.eventos.append(Evento('carabineros', uniform(20, 40)))

    def nuevo_auto(self, *args):  #  no usaremos los args, es solo para llamar la fucion de manera generica.
        # Creamos el auto, añadimos evento salida de la ruta o pana segun corresponda
        auto = Auto(args[0].tiempo, self.largo_ruta)
        print("[NUEVO AUTO]: Auto {} ha iniciado su viaje".format(auto.id))
        self.eventos.append(auto.siguiente_evento)
        # agregamos a la lista de autos
        self.autos.append(auto)
        # Definimos eveto de llegada de proximo auto
        tiempo_proximo_auto = args[0].tiempo + expovariate(self.tasa_llegada_autos)
        self.eventos.append(Evento('nuevo_auto', tiempo_proximo_auto))

    def salida_ruta(self, *args):
        evento = args[0]
        print("[LLEGADA]: Auto {} salió de la ruta".format(evento.auto.id))
        self.autos.remove(evento.auto)
        self.autos_terminaron += 1

    def pana(self, *args):
        evento = args[0]
        print("[PANA en km {}]: Auto {} se quedo en pana".format(
            evento.auto.distancia_recorrida(evento.tiempo), evento.auto.id))
        self.autos.remove(evento.auto)
        self.autos_pana += 1

    def carabineros(self, *args):
        evento = args[0]
        if self.autos:
            auto_detenido = choice(self.autos)
            print("[DETENCION en km {}]: Auto {} se le realizó control de carabineros".format(
                    auto_detenido.distancia_recorrida(evento.tiempo),
                    auto_detenido.id))
            evento_salida_auto = filter(lambda evento: evento.auto == auto_detenido, self.eventos)[0]
            # si detienen a un auto se demorara entre 5 y 15 minutos más en quedar en pana o salir de la ruta
            tiempo_detencion = uniform(5, 10)
            evento_salida_auto.tiempo += tiempo_detencion
            auto_detenido.tiempo_detenido += tiempo_detencion
            self.autos_detenidos += 1
        tiempo_proxima_detencion = self.tiempo_actual + uniform(20, 40)
        self.eventos.append(Evento('carabineros', tiempo_proxima_detencion))

    def run(self):
        self.eventos_iniciales()
        print("\n")
        while self.tiempo_actual <= self.tiempo_maximo and self.eventos:
            self.eventos.sort(key=lambda evento: evento.tiempo)
            evento = self.eventos.pop(0)
            if evento.tiempo < self.tiempo_maximo:
                self.tiempo_actual = evento.tiempo
                self.metodos[evento.nombre](evento)

# %%
def estadisticas_globales(n=10, tiempo_maximo=500):
    estadisticas = list()
    for i in range(n):
        s = Simulacion(tiempo_maximo)
        s.run()  #  va a imprimir varios logs
        estadisticas.append(
            {'detenidos': s.autos_detenidos, "pana": s.autos_pana,
             'terminaron': s.autos_terminaron, "largo": s.largo_ruta})

    print("\n")
    for i in range(n):
        print(
            "En Simulacion {} - {} kms: {} autos se quedaron en pana. {} autos llegaron al final de la ruta. {} autos fueron detenidos".format(
                i, estadisticas[i]["largo"], estadisticas[i]["pana"], estadisticas[i]["terminaron"],
                estadisticas[i]["detenidos"]))
    print("\nEstadisticas Promedio:")
    print("   Promedio largo rutas:        {0:<10.6}".format(
        np.mean([est['largo'] for est in estadisticas])))
    print("   Promedio autos en Pana:        {0:<10.6}".format(
        np.mean([est['pana'] for est in estadisticas])))
    print("   Promedio autos en Llegados:    {0:<10.6}".format(
        np.mean([est['terminaron'] for est in estadisticas])))
    print("   Promedio autos en Detenidos:   {0:<10.6}".format(
        np.mean([est['detenidos'] for est in estadisticas])))

# %%
if __name__ == '__main__':
    estadisticas_globales(n=10)
# Out:
# [NUEVO AUTO]: Auto 785 ha iniciado su viaje
# [NUEVO AUTO]: Auto 786 ha iniciado su viaje
# [DETENCION en km 13.8]: Auto 786 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 787 ha iniciado su viaje
# [DETENCION en km 0.1]: Auto 787 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 788 ha iniciado su viaje
# [DETENCION en km 60.2]: Auto 786 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 789 ha iniciado su viaje
# [NUEVO AUTO]: Auto 790 ha iniciado su viaje
# [NUEVO AUTO]: Auto 791 ha iniciado su viaje
# [DETENCION en km 4.7]: Auto 791 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 792 ha iniciado su viaje
# [DETENCION en km 76.4]: Auto 790 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 793 ha iniciado su viaje
# [DETENCION en km 10.1]: Auto 793 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 794 ha iniciado su viaje
# [NUEVO AUTO]: Auto 795 ha iniciado su viaje
# [DETENCION en km 228.6]: Auto 791 se le realizó control de carabineros
# [LLEGADA]: Auto 787 salió de la ruta
# [NUEVO AUTO]: Auto 796 ha iniciado su viaje
# [LLEGADA]: Auto 789 salió de la ruta
# [NUEVO AUTO]: Auto 797 ha iniciado su viaje
# [DETENCION en km 26.4]: Auto 796 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 798 ha iniciado su viaje
# [DETENCION en km 127.8]: Auto 792 se le realizó control de carabineros
# [LLEGADA]: Auto 791 salió de la ruta
# [DETENCION en km 328.8]: Auto 790 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 799 ha iniciado su viaje
# [DETENCION en km 312.1]: Auto 785 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 800 ha iniciado su viaje
# [LLEGADA]: Auto 790 salió de la ruta
# [DETENCION en km 91.2]: Auto 799 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 801 ha iniciado su viaje
# [LLEGADA]: Auto 797 salió de la ruta
# [DETENCION en km 347.8]: Auto 786 se le realizó control de carabineros
# [LLEGADA]: Auto 794 salió de la ruta
# [NUEVO AUTO]: Auto 802 ha iniciado su viaje
# [NUEVO AUTO]: Auto 803 ha iniciado su viaje
# [LLEGADA]: Auto 795 salió de la ruta
# [NUEVO AUTO]: Auto 804 ha iniciado su viaje
# [NUEVO AUTO]: Auto 805 ha iniciado su viaje
# [DETENCION en km 272.4]: Auto 792 se le realizó control de carabineros
# [LLEGADA]: Auto 785 salió de la ruta
# [LLEGADA]: Auto 796 salió de la ruta
# [LLEGADA]: Auto 786 salió de la ruta
# [DETENCION en km 273.5]: Auto 801 se le realizó control de carabineros
# [LLEGADA]: Auto 798 salió de la ruta
# [LLEGADA]: Auto 800 salió de la ruta
# [NUEVO AUTO]: Auto 806 ha iniciado su viaje
# [LLEGADA]: Auto 788 salió de la ruta
# [DETENCION en km 314.5]: Auto 801 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 807 ha iniciado su viaje
#
#
# [NUEVO AUTO]: Auto 808 ha iniciado su viaje
# [NUEVO AUTO]: Auto 809 ha iniciado su viaje
# [NUEVO AUTO]: Auto 810 ha iniciado su viaje
# [NUEVO AUTO]: Auto 811 ha iniciado su viaje
# [DETENCION en km 22.3]: Auto 808 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 812 ha iniciado su viaje
# [NUEVO AUTO]: Auto 813 ha iniciado su viaje
# [NUEVO AUTO]: Auto 814 ha iniciado su viaje
# [NUEVO AUTO]: Auto 815 ha iniciado su viaje
# [NUEVO AUTO]: Auto 816 ha iniciado su viaje
# [DETENCION en km 28.3]: Auto 812 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 817 ha iniciado su viaje
# [NUEVO AUTO]: Auto 818 ha iniciado su viaje
# [NUEVO AUTO]: Auto 819 ha iniciado su viaje
# [DETENCION en km 123.5]: Auto 814 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 820 ha iniciado su viaje
# [NUEVO AUTO]: Auto 821 ha iniciado su viaje
# [DETENCION en km 105.1]: Auto 808 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 822 ha iniciado su viaje
# [NUEVO AUTO]: Auto 823 ha iniciado su viaje
# [NUEVO AUTO]: Auto 824 ha iniciado su viaje
# [DETENCION en km 0.7]: Auto 824 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 825 ha iniciado su viaje
# [NUEVO AUTO]: Auto 826 ha iniciado su viaje
# [DETENCION en km 160.2]: Auto 810 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 827 ha iniciado su viaje
# [NUEVO AUTO]: Auto 828 ha iniciado su viaje
# [LLEGADA]: Auto 814 salió de la ruta
# [NUEVO AUTO]: Auto 829 ha iniciado su viaje
# [NUEVO AUTO]: Auto 830 ha iniciado su viaje
# [LLEGADA]: Auto 818 salió de la ruta
# [DETENCION en km 170.0]: Auto 822 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 831 ha iniciado su viaje
# [DETENCION en km 135.5]: Auto 828 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 832 ha iniciado su viaje
# [LLEGADA]: Auto 821 salió de la ruta
# [NUEVO AUTO]: Auto 833 ha iniciado su viaje
# [DETENCION en km 221.7]: Auto 827 se le realizó control de carabineros
# [LLEGADA]: Auto 815 salió de la ruta
# [LLEGADA]: Auto 817 salió de la ruta
# [NUEVO AUTO]: Auto 834 ha iniciado su viaje
# [DETENCION en km 267.6]: Auto 828 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 835 ha iniciado su viaje
# [NUEVO AUTO]: Auto 836 ha iniciado su viaje
# [NUEVO AUTO]: Auto 837 ha iniciado su viaje
# [NUEVO AUTO]: Auto 838 ha iniciado su viaje
# [NUEVO AUTO]: Auto 839 ha iniciado su viaje
# [LLEGADA]: Auto 825 salió de la ruta
# [DETENCION en km 282.1]: Auto 813 se le realizó control de carabineros
# [LLEGADA]: Auto 829 salió de la ruta
# [LLEGADA]: Auto 827 salió de la ruta
# [LLEGADA]: Auto 830 salió de la ruta
# [LLEGADA]: Auto 828 salió de la ruta
# [NUEVO AUTO]: Auto 840 ha iniciado su viaje
# [DETENCION en km 89.3]: Auto 833 se le realizó control de carabineros
# [LLEGADA]: Auto 822 salió de la ruta
# [LLEGADA]: Auto 823 salió de la ruta
# [NUEVO AUTO]: Auto 841 ha iniciado su viaje
# [LLEGADA]: Auto 824 salió de la ruta
# [DETENCION en km 323.0]: Auto 813 se le realizó control de carabineros
# [DETENCION en km 298.6]: Auto 820 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 842 ha iniciado su viaje
# [NUEVO AUTO]: Auto 843 ha iniciado su viaje
# [NUEVO AUTO]: Auto 844 ha iniciado su viaje
# [NUEVO AUTO]: Auto 845 ha iniciado su viaje
# [NUEVO AUTO]: Auto 846 ha iniciado su viaje
# [LLEGADA]: Auto 834 salió de la ruta
# [DETENCION en km 375.0]: Auto 816 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 847 ha iniciado su viaje
# [NUEVO AUTO]: Auto 848 ha iniciado su viaje
# [LLEGADA]: Auto 835 salió de la ruta
# [LLEGADA]: Auto 809 salió de la ruta
# [LLEGADA]: Auto 831 salió de la ruta
# [NUEVO AUTO]: Auto 849 ha iniciado su viaje
# [NUEVO AUTO]: Auto 850 ha iniciado su viaje
# [NUEVO AUTO]: Auto 851 ha iniciado su viaje
# [LLEGADA]: Auto 811 salió de la ruta
# [NUEVO AUTO]: Auto 852 ha iniciado su viaje
# [LLEGADA]: Auto 808 salió de la ruta
# [NUEVO AUTO]: Auto 853 ha iniciado su viaje
# [DETENCION en km 316.5]: Auto 837 se le realizó control de carabineros
# [LLEGADA]: Auto 810 salió de la ruta
# [LLEGADA]: Auto 812 salió de la ruta
# [NUEVO AUTO]: Auto 854 ha iniciado su viaje
# [LLEGADA]: Auto 813 salió de la ruta
# [PANA en km 420.4]: Auto 819 se quedo en pana
# [NUEVO AUTO]: Auto 855 ha iniciado su viaje
# [DETENCION en km 255.4]: Auto 832 se le realizó control de carabineros
# [LLEGADA]: Auto 816 salió de la ruta
# [NUEVO AUTO]: Auto 856 ha iniciado su viaje
#
#
# [NUEVO AUTO]: Auto 857 ha iniciado su viaje
# [NUEVO AUTO]: Auto 858 ha iniciado su viaje
# [NUEVO AUTO]: Auto 859 ha iniciado su viaje
# [NUEVO AUTO]: Auto 860 ha iniciado su viaje
# [NUEVO AUTO]: Auto 861 ha iniciado su viaje
# [NUEVO AUTO]: Auto 862 ha iniciado su viaje
# [NUEVO AUTO]: Auto 863 ha iniciado su viaje
# [DETENCION en km 42.1]: Auto 863 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 864 ha iniciado su viaje
# [NUEVO AUTO]: Auto 865 ha iniciado su viaje
# [NUEVO AUTO]: Auto 866 ha iniciado su viaje
# [DETENCION en km 39.5]: Auto 862 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 867 ha iniciado su viaje
# [NUEVO AUTO]: Auto 868 ha iniciado su viaje
# [NUEVO AUTO]: Auto 869 ha iniciado su viaje
# [NUEVO AUTO]: Auto 870 ha iniciado su viaje
# [NUEVO AUTO]: Auto 871 ha iniciado su viaje
# [DETENCION en km 58.4]: Auto 862 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 872 ha iniciado su viaje
# [NUEVO AUTO]: Auto 873 ha iniciado su viaje
# [DETENCION en km 2.9]: Auto 873 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 874 ha iniciado su viaje
# [NUEVO AUTO]: Auto 875 ha iniciado su viaje
# [NUEVO AUTO]: Auto 876 ha iniciado su viaje
# [NUEVO AUTO]: Auto 877 ha iniciado su viaje
# [NUEVO AUTO]: Auto 878 ha iniciado su viaje
# [DETENCION en km 85.4]: Auto 868 se le realizó control de carabineros
# [LLEGADA]: Auto 857 salió de la ruta
# [NUEVO AUTO]: Auto 879 ha iniciado su viaje
# [PANA en km 459.0]: Auto 858 se quedo en pana
# [NUEVO AUTO]: Auto 880 ha iniciado su viaje
# [LLEGADA]: Auto 861 salió de la ruta
# [NUEVO AUTO]: Auto 881 ha iniciado su viaje
# [NUEVO AUTO]: Auto 882 ha iniciado su viaje
# [DETENCION en km 167.6]: Auto 860 se le realizó control de carabineros
# [LLEGADA]: Auto 863 salió de la ruta
# [NUEVO AUTO]: Auto 883 ha iniciado su viaje
# [NUEVO AUTO]: Auto 884 ha iniciado su viaje
# [DETENCION en km 108.8]: Auto 881 se le realizó control de carabineros
# [LLEGADA]: Auto 867 salió de la ruta
# [NUEVO AUTO]: Auto 885 ha iniciado su viaje
# [LLEGADA]: Auto 869 salió de la ruta
# [NUEVO AUTO]: Auto 886 ha iniciado su viaje
# [NUEVO AUTO]: Auto 887 ha iniciado su viaje
# [NUEVO AUTO]: Auto 888 ha iniciado su viaje
# [LLEGADA]: Auto 859 salió de la ruta
# [LLEGADA]: Auto 871 salió de la ruta
# [NUEVO AUTO]: Auto 889 ha iniciado su viaje
# [DETENCION en km 359.6]: Auto 873 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 890 ha iniciado su viaje
# [LLEGADA]: Auto 872 salió de la ruta
# [PANA en km 428.2]: Auto 864 se quedo en pana
# [PANA en km 429.9]: Auto 865 se quedo en pana
# [PANA en km 423.1]: Auto 873 se quedo en pana
# [DETENCION en km 114.6]: Auto 880 se le realizó control de carabineros
# [LLEGADA]: Auto 875 salió de la ruta
# [PANA en km 439.8]: Auto 876 se quedo en pana
# [NUEVO AUTO]: Auto 891 ha iniciado su viaje
# [DETENCION en km 238.2]: Auto 870 se le realizó control de carabineros
# [LLEGADA]: Auto 879 salió de la ruta
# [NUEVO AUTO]: Auto 892 ha iniciado su viaje
# [LLEGADA]: Auto 882 salió de la ruta
# [DETENCION en km 281.4]: Auto 866 se le realizó control de carabineros
# [LLEGADA]: Auto 881 salió de la ruta
# [LLEGADA]: Auto 883 salió de la ruta
# [PANA en km 451.0]: Auto 877 se quedo en pana
# [DETENCION en km 300.1]: Auto 866 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 893 ha iniciado su viaje
# [LLEGADA]: Auto 886 salió de la ruta
# [DETENCION en km 308.7]: Auto 870 se le realizó control de carabineros
# [LLEGADA]: Auto 889 salió de la ruta
# [NUEVO AUTO]: Auto 894 ha iniciado su viaje
# [DETENCION en km 398.1]: Auto 860 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 895 ha iniciado su viaje
# [LLEGADA]: Auto 884 salió de la ruta
# [NUEVO AUTO]: Auto 896 ha iniciado su viaje
# [DETENCION en km 242.1]: Auto 892 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 897 ha iniciado su viaje
# [LLEGADA]: Auto 887 salió de la ruta
# [LLEGADA]: Auto 888 salió de la ruta
# [NUEVO AUTO]: Auto 898 ha iniciado su viaje
# [DETENCION en km 386.1]: Auto 870 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 899 ha iniciado su viaje
# [LLEGADA]: Auto 860 salió de la ruta
#
#
# [NUEVO AUTO]: Auto 900 ha iniciado su viaje
# [NUEVO AUTO]: Auto 901 ha iniciado su viaje
# [DETENCION en km 75.6]: Auto 900 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 902 ha iniciado su viaje
# [NUEVO AUTO]: Auto 903 ha iniciado su viaje
# [NUEVO AUTO]: Auto 904 ha iniciado su viaje
# [NUEVO AUTO]: Auto 905 ha iniciado su viaje
# [DETENCION en km 5.5]: Auto 905 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 906 ha iniciado su viaje
# [DETENCION en km 62.6]: Auto 901 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 907 ha iniciado su viaje
# [NUEVO AUTO]: Auto 908 ha iniciado su viaje
# [NUEVO AUTO]: Auto 909 ha iniciado su viaje
# [DETENCION en km 21.6]: Auto 909 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 910 ha iniciado su viaje
# [NUEVO AUTO]: Auto 911 ha iniciado su viaje
# [NUEVO AUTO]: Auto 912 ha iniciado su viaje
# [NUEVO AUTO]: Auto 913 ha iniciado su viaje
# [DETENCION en km 42.3]: Auto 908 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 914 ha iniciado su viaje
# [NUEVO AUTO]: Auto 915 ha iniciado su viaje
# [NUEVO AUTO]: Auto 916 ha iniciado su viaje
# [LLEGADA]: Auto 900 salió de la ruta
# [DETENCION en km 70.0]: Auto 914 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 917 ha iniciado su viaje
# [NUEVO AUTO]: Auto 918 ha iniciado su viaje
# [NUEVO AUTO]: Auto 919 ha iniciado su viaje
# [NUEVO AUTO]: Auto 920 ha iniciado su viaje
# [LLEGADA]: Auto 906 salió de la ruta
# [DETENCION en km 159.5]: Auto 904 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 921 ha iniciado su viaje
# [NUEVO AUTO]: Auto 922 ha iniciado su viaje
# [LLEGADA]: Auto 902 salió de la ruta
# [NUEVO AUTO]: Auto 923 ha iniciado su viaje
# [DETENCION en km 63.3]: Auto 921 se le realizó control de carabineros
# [LLEGADA]: Auto 911 salió de la ruta
# [NUEVO AUTO]: Auto 924 ha iniciado su viaje
# [NUEVO AUTO]: Auto 925 ha iniciado su viaje
# [NUEVO AUTO]: Auto 926 ha iniciado su viaje
# [DETENCION en km 208.9]: Auto 904 se le realizó control de carabineros
# [LLEGADA]: Auto 915 salió de la ruta
# [NUEVO AUTO]: Auto 927 ha iniciado su viaje
# [NUEVO AUTO]: Auto 928 ha iniciado su viaje
# [NUEVO AUTO]: Auto 929 ha iniciado su viaje
# [NUEVO AUTO]: Auto 930 ha iniciado su viaje
# [DETENCION en km 120.0]: Auto 923 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 931 ha iniciado su viaje
# [LLEGADA]: Auto 909 salió de la ruta
# [LLEGADA]: Auto 918 salió de la ruta
# [LLEGADA]: Auto 910 salió de la ruta
# [DETENCION en km 221.6]: Auto 926 se le realizó control de carabineros
# [LLEGADA]: Auto 913 salió de la ruta
# [NUEVO AUTO]: Auto 932 ha iniciado su viaje
# [NUEVO AUTO]: Auto 933 ha iniciado su viaje
# [NUEVO AUTO]: Auto 934 ha iniciado su viaje
# [LLEGADA]: Auto 916 salió de la ruta
# [LLEGADA]: Auto 914 salió de la ruta
# [DETENCION en km 162.8]: Auto 931 se le realizó control de carabineros
# [PANA en km 411.0]: Auto 922 se quedo en pana
# [NUEVO AUTO]: Auto 935 ha iniciado su viaje
# [LLEGADA]: Auto 921 salió de la ruta
# [NUEVO AUTO]: Auto 936 ha iniciado su viaje
# [LLEGADA]: Auto 919 salió de la ruta
# [DETENCION en km 305.9]: Auto 907 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 937 ha iniciado su viaje
# [LLEGADA]: Auto 920 salió de la ruta
# [NUEVO AUTO]: Auto 938 ha iniciado su viaje
# [NUEVO AUTO]: Auto 939 ha iniciado su viaje
# [LLEGADA]: Auto 926 salió de la ruta
# [DETENCION en km 354.4]: Auto 905 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 940 ha iniciado su viaje
# [NUEVO AUTO]: Auto 941 ha iniciado su viaje
# [NUEVO AUTO]: Auto 942 ha iniciado su viaje
# [NUEVO AUTO]: Auto 943 ha iniciado su viaje
# [LLEGADA]: Auto 930 salió de la ruta
# [LLEGADA]: Auto 901 salió de la ruta
# [LLEGADA]: Auto 903 salió de la ruta
# [DETENCION en km 391.4]: Auto 904 se le realizó control de carabineros
# [LLEGADA]: Auto 931 salió de la ruta
# [LLEGADA]: Auto 923 salió de la ruta
# [DETENCION en km 146.9]: Auto 938 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 944 ha iniciado su viaje
# [LLEGADA]: Auto 932 salió de la ruta
# [LLEGADA]: Auto 905 salió de la ruta
#
#
# [NUEVO AUTO]: Auto 945 ha iniciado su viaje
# [NUEVO AUTO]: Auto 946 ha iniciado su viaje
# [NUEVO AUTO]: Auto 947 ha iniciado su viaje
# [NUEVO AUTO]: Auto 948 ha iniciado su viaje
# [DETENCION en km 14.6]: Auto 947 se le realizó control de carabineros
# [DETENCION en km 94.6]: Auto 946 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 949 ha iniciado su viaje
# [NUEVO AUTO]: Auto 950 ha iniciado su viaje
# [DETENCION en km 147.3]: Auto 946 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 951 ha iniciado su viaje
# [NUEVO AUTO]: Auto 952 ha iniciado su viaje
# [DETENCION en km 141.4]: Auto 949 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 953 ha iniciado su viaje
# [NUEVO AUTO]: Auto 954 ha iniciado su viaje
# [LLEGADA]: Auto 945 salió de la ruta
# [NUEVO AUTO]: Auto 955 ha iniciado su viaje
# [NUEVO AUTO]: Auto 956 ha iniciado su viaje
# [DETENCION en km 192.1]: Auto 947 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 957 ha iniciado su viaje
# [DETENCION en km 122.8]: Auto 948 se le realizó control de carabineros
# [LLEGADA]: Auto 946 salió de la ruta
# [LLEGADA]: Auto 949 salió de la ruta
# [LLEGADA]: Auto 950 salió de la ruta
# [DETENCION en km 79.6]: Auto 953 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 958 ha iniciado su viaje
# [LLEGADA]: Auto 947 salió de la ruta
# [DETENCION en km 108.0]: Auto 954 se le realizó control de carabineros
# [LLEGADA]: Auto 955 salió de la ruta
# [NUEVO AUTO]: Auto 959 ha iniciado su viaje
# [DETENCION en km 178.6]: Auto 951 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 960 ha iniciado su viaje
# [DETENCION en km 99.4]: Auto 959 se le realizó control de carabineros
# [LLEGADA]: Auto 956 salió de la ruta
# [NUEVO AUTO]: Auto 961 ha iniciado su viaje
# [NUEVO AUTO]: Auto 962 ha iniciado su viaje
# [DETENCION en km 293.7]: Auto 948 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 963 ha iniciado su viaje
# [DETENCION en km 269.4]: Auto 952 se le realizó control de carabineros
# [LLEGADA]: Auto 958 salió de la ruta
# [DETENCION en km 59.4]: Auto 963 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 964 ha iniciado su viaje
# [NUEVO AUTO]: Auto 965 ha iniciado su viaje
# [LLEGADA]: Auto 948 salió de la ruta
# [NUEVO AUTO]: Auto 966 ha iniciado su viaje
# [DETENCION en km 98.2]: Auto 962 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 967 ha iniciado su viaje
# [LLEGADA]: Auto 959 salió de la ruta
# [NUEVO AUTO]: Auto 968 ha iniciado su viaje
# [NUEVO AUTO]: Auto 969 ha iniciado su viaje
# [NUEVO AUTO]: Auto 970 ha iniciado su viaje
# [LLEGADA]: Auto 951 salió de la ruta
# [LLEGADA]: Auto 952 salió de la ruta
# [DETENCION en km 341.4]: Auto 953 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 971 ha iniciado su viaje
# [NUEVO AUTO]: Auto 972 ha iniciado su viaje
# [LLEGADA]: Auto 960 salió de la ruta
# [NUEVO AUTO]: Auto 973 ha iniciado su viaje
# [NUEVO AUTO]: Auto 974 ha iniciado su viaje
# [LLEGADA]: Auto 953 salió de la ruta
# [LLEGADA]: Auto 961 salió de la ruta
# [NUEVO AUTO]: Auto 975 ha iniciado su viaje
# [LLEGADA]: Auto 954 salió de la ruta
# [DETENCION en km 19.0]: Auto 975 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 976 ha iniciado su viaje
#
#
# [NUEVO AUTO]: Auto 977 ha iniciado su viaje
# [NUEVO AUTO]: Auto 978 ha iniciado su viaje
# [NUEVO AUTO]: Auto 979 ha iniciado su viaje
# [NUEVO AUTO]: Auto 980 ha iniciado su viaje
# [NUEVO AUTO]: Auto 981 ha iniciado su viaje
# [DETENCION en km 4.8]: Auto 981 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 982 ha iniciado su viaje
# [NUEVO AUTO]: Auto 983 ha iniciado su viaje
# [NUEVO AUTO]: Auto 984 ha iniciado su viaje
# [DETENCION en km 117.2]: Auto 977 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 985 ha iniciado su viaje
# [NUEVO AUTO]: Auto 986 ha iniciado su viaje
# [NUEVO AUTO]: Auto 987 ha iniciado su viaje
# [NUEVO AUTO]: Auto 988 ha iniciado su viaje
# [DETENCION en km 66.4]: Auto 985 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 989 ha iniciado su viaje
# [NUEVO AUTO]: Auto 990 ha iniciado su viaje
# [NUEVO AUTO]: Auto 991 ha iniciado su viaje
# [DETENCION en km 100.9]: Auto 986 se le realizó control de carabineros
# [LLEGADA]: Auto 979 salió de la ruta
# [DETENCION en km 116.0]: Auto 986 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 992 ha iniciado su viaje
# [NUEVO AUTO]: Auto 993 ha iniciado su viaje
# [NUEVO AUTO]: Auto 994 ha iniciado su viaje
# [LLEGADA]: Auto 983 salió de la ruta
# [NUEVO AUTO]: Auto 995 ha iniciado su viaje
# [DETENCION en km 103.5]: Auto 987 se le realizó control de carabineros
# [LLEGADA]: Auto 988 salió de la ruta
# [LLEGADA]: Auto 985 salió de la ruta
# [LLEGADA]: Auto 978 salió de la ruta
# [LLEGADA]: Auto 977 salió de la ruta
# [DETENCION en km 132.0]: Auto 984 se le realizó control de carabineros
# [DETENCION en km 148.4]: Auto 984 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 996 ha iniciado su viaje
# [LLEGADA]: Auto 982 salió de la ruta
# [NUEVO AUTO]: Auto 997 ha iniciado su viaje
# [LLEGADA]: Auto 981 salió de la ruta
# [NUEVO AUTO]: Auto 998 ha iniciado su viaje
# [NUEVO AUTO]: Auto 999 ha iniciado su viaje
# [DETENCION en km 225.9]: Auto 992 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1000 ha iniciado su viaje
# [LLEGADA]: Auto 986 salió de la ruta
# [LLEGADA]: Auto 989 salió de la ruta
# [DETENCION en km 53.1]: Auto 998 se le realizó control de carabineros
# [LLEGADA]: Auto 995 salió de la ruta
# [DETENCION en km 69.3]: Auto 998 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1001 ha iniciado su viaje
# [LLEGADA]: Auto 993 salió de la ruta
# [DETENCION en km 333.0]: Auto 994 se le realizó control de carabineros
# [LLEGADA]: Auto 992 salió de la ruta
# [NUEVO AUTO]: Auto 1002 ha iniciado su viaje
# [LLEGADA]: Auto 997 salió de la ruta
# [DETENCION en km 20.2]: Auto 1002 se le realizó control de carabineros
# [LLEGADA]: Auto 994 salió de la ruta
# [NUEVO AUTO]: Auto 1003 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1004 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1005 ha iniciado su viaje
# [DETENCION en km 7.5]: Auto 1005 se le realizó control de carabineros
# [LLEGADA]: Auto 980 salió de la ruta
# [NUEVO AUTO]: Auto 1006 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1007 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1008 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1009 ha iniciado su viaje
# [DETENCION en km 180.2]: Auto 996 se le realizó control de carabineros
# [DETENCION en km 46.3]: Auto 1005 se le realizó control de carabineros
# [LLEGADA]: Auto 999 salió de la ruta
# [NUEVO AUTO]: Auto 1010 ha iniciado su viaje
# [LLEGADA]: Auto 984 salió de la ruta
# [LLEGADA]: Auto 987 salió de la ruta
# [LLEGADA]: Auto 1000 salió de la ruta
# [NUEVO AUTO]: Auto 1011 ha iniciado su viaje
# [DETENCION en km 227.0]: Auto 996 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1012 ha iniciado su viaje
# [LLEGADA]: Auto 990 salió de la ruta
# [LLEGADA]: Auto 991 salió de la ruta
# [NUEVO AUTO]: Auto 1013 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1014 ha iniciado su viaje
# [LLEGADA]: Auto 1001 salió de la ruta
# [NUEVO AUTO]: Auto 1015 ha iniciado su viaje
# [DETENCION en km 129.9]: Auto 1003 se le realizó control de carabineros
#
#
# [NUEVO AUTO]: Auto 1016 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1017 ha iniciado su viaje
# [DETENCION en km 80.3]: Auto 1016 se le realizó control de carabineros
# [DETENCION en km 50.6]: Auto 1017 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1018 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1019 ha iniciado su viaje
# [DETENCION en km 71.9]: Auto 1017 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1020 ha iniciado su viaje
# [DETENCION en km 45.9]: Auto 1020 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1021 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1022 ha iniciado su viaje
# [LLEGADA]: Auto 1016 salió de la ruta
# [NUEVO AUTO]: Auto 1023 ha iniciado su viaje
# [DETENCION en km 241.7]: Auto 1018 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1024 ha iniciado su viaje
# [DETENCION en km 209.6]: Auto 1020 se le realizó control de carabineros
# [LLEGADA]: Auto 1018 salió de la ruta
# [DETENCION en km 71.5]: Auto 1023 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1025 ha iniciado su viaje
# [LLEGADA]: Auto 1020 salió de la ruta
# [DETENCION en km 103.9]: Auto 1022 se le realizó control de carabineros
# [LLEGADA]: Auto 1021 salió de la ruta
# [LLEGADA]: Auto 1019 salió de la ruta
# [NUEVO AUTO]: Auto 1026 ha iniciado su viaje
# [DETENCION en km 116.8]: Auto 1024 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1027 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1028 ha iniciado su viaje
# [DETENCION en km 157.8]: Auto 1022 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1029 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1030 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1031 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1032 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1033 ha iniciado su viaje
# [DETENCION en km 1.4]: Auto 1033 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1034 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1035 ha iniciado su viaje
# [LLEGADA]: Auto 1025 salió de la ruta
# [NUEVO AUTO]: Auto 1036 ha iniciado su viaje
# [DETENCION en km 121.6]: Auto 1030 se le realizó control de carabineros
# [LLEGADA]: Auto 1026 salió de la ruta
# [DETENCION en km 231.6]: Auto 1023 se le realizó control de carabineros
# [LLEGADA]: Auto 1017 salió de la ruta
# [DETENCION en km 83.5]: Auto 1032 se le realizó control de carabineros
# [LLEGADA]: Auto 1028 salió de la ruta
# [NUEVO AUTO]: Auto 1037 ha iniciado su viaje
# [DETENCION en km 274.4]: Auto 1023 se le realizó control de carabineros
# [LLEGADA]: Auto 1027 salió de la ruta
# [NUEVO AUTO]: Auto 1038 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1039 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1040 ha iniciado su viaje
# [DETENCION en km 125.1]: Auto 1036 se le realizó control de carabineros
# [LLEGADA]: Auto 1029 salió de la ruta
# [NUEVO AUTO]: Auto 1041 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1042 ha iniciado su viaje
# [LLEGADA]: Auto 1030 salió de la ruta
#
#
# [NUEVO AUTO]: Auto 1043 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1044 ha iniciado su viaje
# [DETENCION en km 7.7]: Auto 1044 se le realizó control de carabineros
# [DETENCION en km 47.9]: Auto 1044 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1045 ha iniciado su viaje
# [DETENCION en km 21.5]: Auto 1045 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1046 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1047 ha iniciado su viaje
# [DETENCION en km 139.8]: Auto 1044 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1048 ha iniciado su viaje
# [DETENCION en km 126.4]: Auto 1046 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1049 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1050 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1051 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1052 ha iniciado su viaje
# [DETENCION en km 1.1]: Auto 1049 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1053 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1054 ha iniciado su viaje
# [DETENCION en km 268.9]: Auto 1046 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1055 ha iniciado su viaje
# [LLEGADA]: Auto 1043 salió de la ruta
# [NUEVO AUTO]: Auto 1056 ha iniciado su viaje
# [DETENCION en km 56.7]: Auto 1054 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1057 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1058 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1059 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1060 ha iniciado su viaje
# [DETENCION en km 75.6]: Auto 1054 se le realizó control de carabineros
# [LLEGADA]: Auto 1048 salió de la ruta
# [LLEGADA]: Auto 1046 salió de la ruta
# [LLEGADA]: Auto 1044 salió de la ruta
# [DETENCION en km 96.9]: Auto 1054 se le realizó control de carabineros
# [PANA en km 418.4]: Auto 1051 se quedo en pana
# [NUEVO AUTO]: Auto 1061 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1062 ha iniciado su viaje
# [DETENCION en km 272.6]: Auto 1056 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1063 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1064 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1065 ha iniciado su viaje
# [LLEGADA]: Auto 1055 salió de la ruta
# [DETENCION en km 152.4]: Auto 1054 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1066 ha iniciado su viaje
# [LLEGADA]: Auto 1050 salió de la ruta
# [LLEGADA]: Auto 1052 salió de la ruta
# [LLEGADA]: Auto 1049 salió de la ruta
# [PANA en km 417.3]: Auto 1056 se quedo en pana
# [DETENCION en km 192.1]: Auto 1062 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1067 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1068 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1069 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1070 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1071 ha iniciado su viaje
# [DETENCION en km 137.8]: Auto 1061 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1072 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1073 ha iniciado su viaje
# [LLEGADA]: Auto 1057 salió de la ruta
# [DETENCION en km 245.2]: Auto 1054 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1074 ha iniciado su viaje
# [LLEGADA]: Auto 1063 salió de la ruta
# [NUEVO AUTO]: Auto 1075 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1076 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1077 ha iniciado su viaje
# [PANA en km 422.3]: Auto 1045 se quedo en pana
# [NUEVO AUTO]: Auto 1078 ha iniciado su viaje
# [DETENCION en km 45.3]: Auto 1076 se le realizó control de carabineros
# [LLEGADA]: Auto 1064 salió de la ruta
#
#
# [NUEVO AUTO]: Auto 1079 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1080 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1081 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1082 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1083 ha iniciado su viaje
# [DETENCION en km 57.6]: Auto 1079 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1084 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1085 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1086 ha iniciado su viaje
# [DETENCION en km 176.8]: Auto 1080 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1087 ha iniciado su viaje
# [DETENCION en km 261.2]: Auto 1080 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1088 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1089 ha iniciado su viaje
# [DETENCION en km 52.0]: Auto 1089 se le realizó control de carabineros
# [LLEGADA]: Auto 1080 salió de la ruta
# [DETENCION en km 214.9]: Auto 1085 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1090 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1091 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1092 ha iniciado su viaje
# [DETENCION en km 305.2]: Auto 1084 se le realizó control de carabineros
# [LLEGADA]: Auto 1087 salió de la ruta
# [LLEGADA]: Auto 1081 salió de la ruta
# [LLEGADA]: Auto 1082 salió de la ruta
# [LLEGADA]: Auto 1079 salió de la ruta
# [NUEVO AUTO]: Auto 1093 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1094 ha iniciado su viaje
# [LLEGADA]: Auto 1083 salió de la ruta
# [DETENCION en km 345.1]: Auto 1084 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1095 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1096 ha iniciado su viaje
# [LLEGADA]: Auto 1086 salió de la ruta
# [LLEGADA]: Auto 1089 salió de la ruta
# [DETENCION en km 234.5]: Auto 1092 se le realizó control de carabineros
# [LLEGADA]: Auto 1085 salió de la ruta
# [LLEGADA]: Auto 1084 salió de la ruta
# [NUEVO AUTO]: Auto 1097 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1098 ha iniciado su viaje
# [DETENCION en km 279.0]: Auto 1092 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1099 ha iniciado su viaje
# [LLEGADA]: Auto 1088 salió de la ruta
# [DETENCION en km 148.3]: Auto 1090 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1100 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1101 ha iniciado su viaje
# [LLEGADA]: Auto 1092 salió de la ruta
# [LLEGADA]: Auto 1093 salió de la ruta
# [LLEGADA]: Auto 1094 salió de la ruta
# [DETENCION en km 359.9]: Auto 1091 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1102 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1103 ha iniciado su viaje
# [LLEGADA]: Auto 1095 salió de la ruta
# [DETENCION en km 77.6]: Auto 1099 se le realizó control de carabineros
# [LLEGADA]: Auto 1096 salió de la ruta
# [LLEGADA]: Auto 1091 salió de la ruta
# [DETENCION en km 220.6]: Auto 1090 se le realizó control de carabineros
# [LLEGADA]: Auto 1098 salió de la ruta
# [NUEVO AUTO]: Auto 1104 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1105 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1106 ha iniciado su viaje
# [DETENCION en km 56.6]: Auto 1104 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1107 ha iniciado su viaje
# [DETENCION en km 102.8]: Auto 1104 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1108 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1109 ha iniciado su viaje
#
#
# [NUEVO AUTO]: Auto 1110 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1111 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1112 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1113 ha iniciado su viaje
# [DETENCION en km 10.2]: Auto 1113 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1114 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1115 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1116 ha iniciado su viaje
# [DETENCION en km 37.2]: Auto 1114 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1117 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1118 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1119 ha iniciado su viaje
# [DETENCION en km 15.6]: Auto 1118 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1120 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1121 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1122 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1123 ha iniciado su viaje
# [DETENCION en km 213.0]: Auto 1117 se le realizó control de carabineros
# [LLEGADA]: Auto 1110 salió de la ruta
# [NUEVO AUTO]: Auto 1124 ha iniciado su viaje
# [LLEGADA]: Auto 1111 salió de la ruta
# [DETENCION en km 40.2]: Auto 1124 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1125 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1126 ha iniciado su viaje
# [DETENCION en km 369.6]: Auto 1117 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1127 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1128 ha iniciado su viaje
# [DETENCION en km 145.9]: Auto 1118 se le realizó control de carabineros
# [LLEGADA]: Auto 1117 salió de la ruta
# [NUEVO AUTO]: Auto 1129 ha iniciado su viaje
# [LLEGADA]: Auto 1112 salió de la ruta
# [DETENCION en km 321.4]: Auto 1119 se le realizó control de carabineros
# [LLEGADA]: Auto 1121 salió de la ruta
# [LLEGADA]: Auto 1115 salió de la ruta
# [PANA en km 460.1]: Auto 1114 se quedo en pana
# [DETENCION en km 179.3]: Auto 1122 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1130 ha iniciado su viaje
# [DETENCION en km 462.0]: Auto 1124 se le realizó control de carabineros
# [LLEGADA]: Auto 1124 salió de la ruta
# [LLEGADA]: Auto 1119 salió de la ruta
# [LLEGADA]: Auto 1125 salió de la ruta
# [LLEGADA]: Auto 1126 salió de la ruta
# [NUEVO AUTO]: Auto 1131 ha iniciado su viaje
# [DETENCION en km 232.9]: Auto 1123 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1132 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1133 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1134 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1135 ha iniciado su viaje
# [LLEGADA]: Auto 1128 salió de la ruta
# [DETENCION en km 191.7]: Auto 1127 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1136 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1137 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1138 ha iniciado su viaje
# [DETENCION en km 314.1]: Auto 1120 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1139 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1140 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1141 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1142 ha iniciado su viaje
# [DETENCION en km 229.3]: Auto 1133 se le realizó control de carabineros
# [NUEVO AUTO]: Auto 1143 ha iniciado su viaje
# [NUEVO AUTO]: Auto 1144 ha iniciado su viaje
# [LLEGADA]: Auto 1129 salió de la ruta
# [DETENCION en km 64.9]: Auto 1139 se le realizó control de carabineros
#
#
# En Simulacion 0 - 401 kms: 0 autos se quedaron en pana. 13 autos llegaron al final de la ruta. 16 autos fueron detenidos
# En Simulacion 1 - 436 kms: 1 autos se quedaron en pana. 23 autos llegaron al final de la ruta. 17 autos fueron detenidos
# En Simulacion 2 - 465 kms: 6 autos se quedaron en pana. 19 autos llegaron al final de la ruta. 16 autos fueron detenidos
# En Simulacion 3 - 420 kms: 1 autos se quedaron en pana. 22 autos llegaron al final de la ruta. 16 autos fueron detenidos
# En Simulacion 4 - 354 kms: 0 autos se quedaron en pana. 16 autos llegaron al final de la ruta. 16 autos fueron detenidos
# En Simulacion 5 - 357 kms: 0 autos se quedaron en pana. 23 autos llegaron al final de la ruta. 18 autos fueron detenidos
# En Simulacion 6 - 362 kms: 0 autos se quedaron en pana. 12 autos llegaron al final de la ruta. 16 autos fueron detenidos
# En Simulacion 7 - 447 kms: 3 autos se quedaron en pana. 11 autos llegaron al final de la ruta. 16 autos fueron detenidos
# En Simulacion 8 - 408 kms: 0 autos se quedaron en pana. 18 autos llegaron al final de la ruta. 15 autos fueron detenidos
# En Simulacion 9 - 463 kms: 1 autos se quedaron en pana. 12 autos llegaron al final de la ruta. 15 autos fueron detenidos
#
# Estadisticas Promedio:
#    Promedio largo rutas:        411.3
#    Promedio autos en Pana:        1.2
#    Promedio autos en Llegados:    16.9
#    Promedio autos en Detenidos:   16.1
